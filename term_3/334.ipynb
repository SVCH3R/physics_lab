# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# i = np.array([1, 0.8, 0.5, 0.4, 0.3, 0.2])
# k = np.array([764, 524, 450, 375, 299, 225])

i = np.array([0.5, 0.4, 0.3, 0.2])
k = np.array([450, 375, 299, 225])

# %%
# Рассчитываем коэффициенты прямой методом наименьших квадратов
coefficients = np.polyfit(i, k, 1)
slope, intercept = coefficients

# Создаем новый график
plot_1 = plt.figure(figsize=(12*0.9, 10*0.9))
plt.grid(visible=True, linewidth=0.6)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.title('K(i)', fontsize=18)
plt.ylabel('$K$', fontsize=20, rotation=0, ha='right')
plt.xlabel('$I$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16, size=10)
plt.grid(visible=True, linewidth=0.6)

# Рисуем точки
plt.scatter(i, k, label='Original Data')

# Рисуем прямую МНК
plt.plot(i, np.polyval(coefficients, i), label=f'MNK Line: $K = {slope:.2f}I + {intercept:.2f}$', color='red')

plt.xlim(0.15, 0.55)
plt.ylim(200, 500)
plt.legend()
plt.show()

# %%
print( 7.59 * 823 / 751)
2547 * 759 / 831
# Out:
# 8.317669773635153
# 2326.3212996389893
